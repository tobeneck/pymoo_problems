# %% [markdown]
# # Test if evaluated PS fits PF

# %%
from moo.zdt import ZDT1, ZDT2, ZDT3, ZDT4, ZDT6
from helper import plot_front

n_paretos = 100

problem = ZDT1()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="ZDT1").show()

problem = ZDT2()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="ZDT2").show()

problem = ZDT3()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="ZDT3").show()

problem = ZDT4()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="ZDT4").show()

problem = ZDT6()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="ZDT6").show()
