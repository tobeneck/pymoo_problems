# %%
from moo.lz_jmetalpy import LZ09_F1, LZ09_F2, LZ09_F3, LZ09_F4, LZ09_F5, LZ09_F6, LZ09_F7, LZ09_F8, LZ09_F9
from helper import run_test, plot_front

problem=LZ09_F1(n_var=10)
res = run_test(problem)
fig = plot_front(problem, res, "LZ1")
fig.show()

problem=LZ09_F2(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ2").show()

problem=LZ09_F3(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ3").show()

problem=LZ09_F4(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ4").show()

problem=LZ09_F5(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ5").show()

problem=LZ09_F6(n_var=10)
res = run_test(problem)
print(res)
plot_front(problem, res, "LZ6").show()

problem=LZ09_F7(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ7").show()

problem=LZ09_F8(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ8").show()

problem=LZ09_F9(n_var=10)
res = run_test(problem)
plot_front(problem, res, "LZ9").show()
# Out:
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
# <pymoo.core.result.Result object at 0x11c0fe220>

# %% [markdown]
# # Check Variable Range

# %%
from moo.lz_jmetalpy import LZ09_F1, LZ09_F2, LZ09_F3, LZ09_F4, LZ09_F5, LZ09_F6, LZ09_F7, LZ09_F8, LZ09_F9
from helper import run_test

import plotly.express as px

n_var = 5

problem=LZ09_F1(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F1")
fig.show()

problem=LZ09_F2(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F2")
fig.show()

problem=LZ09_F3(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F3")
fig.show()

problem=LZ09_F4(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F4")
fig.show()

problem=LZ09_F5(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F5")
fig.show()

problem=LZ09_F6(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F6")
fig.show()

problem=LZ09_F7(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F7")
fig.show()

problem=LZ09_F8(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F8")
fig.show()

problem=LZ09_F9(n_var=n_var)
res = run_test(problem)
fig = px.violin(res.X, points='all', title="LZ09_F9")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 n_var = 5
#       8 problem=LZ09_F1(n_var=n_var)
# ----> 9 res = run_test(problem)
#      10 fig = px.strip(res.X, title="LZ09_F1")
#      12 problem=LZ09_F2(n_var=n_var)
#
# File ~/Develop/pymoo_problems/helper.py:30, in run_test(problem, algorithm, n_gen)
#       9 def run_test(problem:Problem,
#      10             algorithm:Algorithm=NSGA2(pop_size=200),
#      11             n_gen=200
#      12             ):
#      13     '''
#      14     Runs one test and returns the res object of the minimize function for evaluation.
#      15
#    (...)
#      28         The result of the test.
#      29     '''
# ---> 30     return minimize(problem,
#      31                 algorithm,
#      32                 ('n_gen', n_gen),
#      33                 seed=1,
#      34                 verbose=False)
#
# File ~/Develop/pymoo_problems/venv/lib/python3.9/site-packages/pymoo/optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
#      69 # store the deep copied algorithm in the result object
#      70 res.algorithm = algorithm
#
# File ~/Develop/pymoo_problems/venv/lib/python3.9/site-packages/pymoo/core/algorithm.py:138, in Algorithm.run(self)
#     136 def run(self):
#     137     while self.has_next():
# --> 138         self.next()
#     139     return self.result()
#
# File ~/Develop/pymoo_problems/venv/lib/python3.9/site-packages/pymoo/core/algorithm.py:159, in Algorithm.next(self)
#     157 if infills is not None:
#     158     self.evaluator.eval(self.problem, infills, algorithm=self)
# --> 159     self.advance(infills=infills)
#     161 # if the algorithm does not follow the infill-advance scheme just call advance
#     162 else:
#     163     self.advance()
#
# File ~/Develop/pymoo_problems/venv/lib/python3.9/site-packages/pymoo/core/algorithm.py:229, in Algorithm.advance(self, infills, **kwargs)
#     227     # always advance to the next iteration - except if the algorithm returns False
#     228     if val is None or val:
# --> 229         self._post_advance()
#     231 # if the algorithm has terminated, then do the finalization steps and return the result
#     232 if self.termination.has_terminated():
#
# File ~/Develop/pymoo_problems/venv/lib/python3.9/site-packages/pymoo/core/algorithm.py:303, in Algorithm._post_advance(self)
#     300 def _post_advance(self):
#     301
#     302     # update the current optimum of the algorithm
# --> 303     self._set_optimum()
#     305     # update the current termination condition of the algorithm
#     306     self.termination.update(self)
#
# File ~/Develop/pymoo_problems/venv/lib/python3.9/site-packages/pymoo/algorithms/moo/nsga2.py:110, in NSGA2._set_optimum(self, **kwargs)
#     107     self.termination = DefaultMultiObjectiveTermination()
#     108     self.tournament_type = 'comp_by_dom_and_crowding'
# --> 110 def _set_optimum(self, **kwargs):
#     111     if not has_feasible(self.pop):
#     112         self.opt = self.pop[[np.argmin(self.pop.get("CV"))]]
#
# KeyboardInterrupt:
