# %% [markdown]
# # MACO base version

# %%
from moo.maco import MACO
from helper import run_test, plot_2d_front

problem=MACO(n_var=10)
res = run_test(problem)
plot_2d_front(res, problem, "MACO Base Version")

# %% [markdown]
# # p-norm variation

# %%
import numpy as np
from moo.maco import MACO
from helper import run_test, plot_2d_front

problem=MACO(n_var=10, p=-np.inf)
res = run_test(problem)
plot_2d_front(res, problem, "MACO p=-inf")

problem=MACO(n_var=10, p=-10)
res = run_test(problem)
plot_2d_front(res, problem, "MACO p=-10")

problem=MACO(n_var=10, p=-2)
res = run_test(problem)
plot_2d_front(res, problem, "MACO p=-2")

# %% [markdown]
# # weigths variation

# %%
from moo.maco import MACO
from helper import run_test, plot_2d_front

problem=MACO(n_var=10, wtype=None)
res = run_test(problem)
plot_2d_front(res, problem, "MACO weights=none")

problem=MACO(n_var=10, wtype="shallow")
res = run_test(problem)
plot_2d_front(res, problem, "MACO weights=shallow")

problem=MACO(n_var=10, wtype="steep")
res = run_test(problem)
plot_2d_front(res, problem, "MACO weights=steep")
# Out:
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False

# %% [markdown]
# # independent sub-problems variation

# %%
from moo.maco import MACO
from helper import run_test, plot_2d_front

problem=MACO(n_var=10, ctype=None)
res = run_test(problem)
plot_2d_front(res, problem, "MACO class=equal")

problem=MACO(n_var=10, ctype="half")
res = run_test(problem)
plot_2d_front(res, problem, "MACO class=half")

problem=MACO(n_var=10, ctype="G3")
res = run_test(problem)
plot_2d_front(res, problem, "MACO class=G3")

problem=MACO(n_var=10, ctype="G4")
res = run_test(problem)
plot_2d_front(res, problem, "MACO class=G4")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 from moo.maco import MACO
#       2 from helper import run_test, plot_2d_front
# ----> 4 problem=MACO(n_var=10, ctype="equal")
#       5 res = run_test(problem)
#       6 plot_2d_front(res, problem, "MACO class=equal")
#
# File ~/Develop/pymoo_problems/moo/maco.py:121, in MACO.__init__(self, n_var, p, weights, classes, ctype, wtype)
#     120 def __init__(self, n_var=10, p=-np.inf, weights=None, classes=None, ctype=None, wtype=None):
# --> 121     classes = get_classes(ctype, classes, n_var)
#     122     weights = get_weights(wtype, weights, n_var)
#     124     assert len(weights) == n_var
#
# File ~/Develop/pymoo_problems/moo/maco.py:100, in get_classes(ctype, classes, N)
#      98 if ctype == "G4":
#      99     return np.array([i // 4 for i in range(N)], dtype=int)
# --> 100 raise NotImplementedError("ctype not known")
#
# NotImplementedError: ctype not known
