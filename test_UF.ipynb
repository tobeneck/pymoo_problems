# %% [markdown]
# # Test if the algorithm finds the true pareto fronts

# %%
from moo.uf import UF1, UF2, UF3, UF8, UF9, UF10
from helper import run_test, plot_front

problem=UF1(n_var=10)
res = run_test(problem)
plot_front(problem, res.F, "UF1").show()

problem=UF2(n_var=10)
res = run_test(problem)
plot_front(problem, res.F, "UF2").show()

problem=UF3(n_var=10)
res = run_test(problem)
plot_front(problem, res.F, "UF3").show()

problem=UF8(n_var=10)
res = run_test(problem)
plot_front(problem, res.F, "UF8").show()

problem=UF9(n_var=10)
res = run_test(problem)
plot_front(problem, res.F, "UF9").show()

problem=UF10(n_var=10)
res = run_test(problem)
plot_front(problem, res.F, "UF10").show()
# Out:
# 22 16
# 22 16

# %% [markdown]
# # Test the pareto sets
#
# The results of PF and PS are visually compared to the reference PS from jmetalpy.

# %%
from moo.uf import UF1, UF2, UF3, UF8, UF9, UF10
from helper import plot_front

n_paretos = 1000

problem = UF1()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="UF1").show()

problem = UF2()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="UF2").show()

problem = UF3()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="UF3").show()

problem = UF8()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="UF8").show()

problem = UF9()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="UF9").show()

problem = UF10()
nds = problem.evaluate(problem._calc_pareto_set(n_paretos))
plot_front(problem, nds, title="UF10").show()
# Out:
# 31 39
# 22 16
# 31 39
# 22 16

# %% [markdown]
# # Check Variable Range

# %%
from moo.uf import UF1, UF2, UF3, UF8, UF9, UF10

import plotly.express as px

n_var = 10

problem=UF1(n_var=n_var)
fig = px.violin(problem._calc_pareto_set(), points='all', title="UF1")
fig.show()

problem=UF2(n_var=n_var)
fig = px.violin(problem._calc_pareto_set(), points='all', title="UF2")
fig.show()

problem=UF3(n_var=n_var)
fig = px.violin(problem._calc_pareto_set(), points='all', title="UF3")
fig.show()

problem=UF8(n_var=n_var)
fig = px.violin(problem._calc_pareto_set(), points='all', title="UF8")
fig.show()

problem=UF9(n_var=n_var)
fig = px.violin(problem._calc_pareto_set(), points='all', title="UF9")
fig.show()
# Out:
# 25 0
