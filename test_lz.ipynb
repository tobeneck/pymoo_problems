# %%
from moo.lz import LZ09_F1, LZ09_F2, LZ09_F3, LZ09_F4, LZ09_F5, LZ09_F6, LZ09_F7, LZ09_F8, LZ09_F9
from helper import run_test, plot_front, plot_result

# problem=LZ09_F1(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F1")

# problem=LZ09_F2(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F2")

# problem=LZ09_F3(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F3")

# problem=LZ09_F4(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F4")

# problem=LZ09_F5(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F5")

problem=LZ09_F6(n_var=10)
res = run_test(problem, n_gen=200)
print(res)
plot_front(res, problem, "LZ09_F6")

# problem=LZ09_F7(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F7")

# problem=LZ09_F8(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F8")

# problem=LZ09_F9(n_var=10)
# res = run_test(problem)
# plot_front(res, problem, "LZ09_F9")
# Out:
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
#
# ...
